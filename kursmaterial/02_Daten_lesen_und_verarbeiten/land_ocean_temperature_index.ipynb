# %%
import pandas as pd

# %%
df = pd.read_csv("land_ocean_temperature_index.txt", header=3, names=["Year", "No_Smoothing", "Lowess(5)"], skip_blank_lines=True, delimiter="     ")
df.head()
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_20136\3797415280.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("land_ocean_temperature_index.txt", header=3, names=["Year", "No_Smoothing", "Lowess(5)"], skip_blank_lines=True, delimiter="     ")
#    Year  No_Smoothing  Lowess(5)
# 0  1880         -0.17      -0.10
# 1  1881         -0.09      -0.13
# 2  1882         -0.11      -0.17
# 3  1883         -0.18      -0.21
# 4  1884         -0.29      -0.24

# %%
df["No_Smoothing"].plot()
# Out:
# <Axes: >
